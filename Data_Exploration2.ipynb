# %%
import json
from datetime import datetime
from pathlib import Path

# %% [markdown]
# ## 1. Open user tweets

# %%
users: dict[str, list[dict]] = {}
for file in Path("data", "user_tweets").glob("*.json"):
    users[file.stem] = json.loads(file.read_bytes())

# %% [markdown]
# ## 2. Looking for the user with the most tweets

# %%
count = 0
user_tweets = {}
for user, tweets in users.items():
    if len(tweets) > count:
        count = len(tweets)
        user_id = user
        user_tweets = users[user]

# %% [markdown]
# ## 3. Looking through the text content of the tweets

# %%
user_urls = []
for i, tweet in enumerate(user_tweets):
    print("Date d'envoi :", datetime.strptime(tweet["created_at"], "%a %b %d %H:%M:%S %z %Y"))
    user_urls.extend([url["expanded_url"] for url in tweet["entities"]["urls"]])
    print(f"\n{tweet['text']}")
    print("----------")
print(f"URLs complètes contenus dans les tweets de l'utilisateur :\n{user_urls}")
# Out:
# Date d'envoi : 2018-06-15 20:41:42+00:00
#
# RT @tv3_ghana: 📌WHAT. A. GAME.
#
# SUSPENSE. DRAMA. SUSPENSE.
#
# 🇵🇹 Portugal 3-3 Spain 🇪🇸
#
# ⚽️ Cristiano Ronaldo Hat-trick
#
# ⚽️ Diego Costa Bra…
# ----------
# Date d'envoi : 2018-06-15 20:41:45+00:00
#
# RT @onua951fm: FULL TIME: Portugal 3:3 Spain
#
# Ronaldo takes centre stage as Portugal draw.
# #WorldCup #3sports
# ----------
# Date d'envoi : 2018-06-15 20:49:17+00:00
#
# Only four players have scored in four consecutive #WorldCup tournaments:
#
# 🇧🇷 Pele
# 🇩🇪 Uwe Seeler
# 🇩🇪 Miroslav Klose… https://t.co/lsgQRQuQ3v
# ----------
# Date d'envoi : 2018-06-15 20:51:12+00:00
#
# How would you describe Ronaldo’s performance tonight?
#
# #WorldCup #ConnectSports https://t.co/eYy0QzIDyT
# ----------
# Date d'envoi : 2018-06-15 20:52:13+00:00
#
# At 33 years and 131 days old, Cristiano Ronaldo is the oldest player with a hat trick at the #WorldCup… https://t.co/GYW0JRjQMl
# ----------
# Date d'envoi : 2018-06-16 09:24:18+00:00
#
# Are you ready for Matchday 3?
#
# 📌 Four #WorldCup games? Some with pre-tournament favourites? On a weekend? Bless the… https://t.co/E83qXkIUUs
# ----------
# Date d'envoi : 2018-06-16 09:27:01+00:00
#
# 📌 How are the men to do battle?
#
# Here's how #Fra and #aus line-up for their #WorldCup game today? #ConnectSports https://t.co/lXF08fTlNr
# ----------
# Date d'envoi : 2018-06-16 09:30:31+00:00
#
# 📌 Nothing like an early morning #WorldCup game to enjoy.
#
# In a few minutes, #France will look to get their World Cu… https://t.co/cKLsStacRj
# ----------
# Date d'envoi : 2018-06-16 09:51:27+00:00
#
# 📌Australia have won only two of their 13 games at the #WorldCup, against Japan in 2006 (3-1) and Serbia in 2010 (2-… https://t.co/rIzktW16QD
# ----------
# Date d'envoi : 2018-06-16 09:53:48+00:00
#
# 📌 Some stats to help you enjoy the game..
#
# Australia and France have met four times, with the Aussies winning once,… https://t.co/rZGn3Djvxp
# ----------
# Date d'envoi : 2018-06-16 11:46:41+00:00
#
# RT @onua951fm: Plenty of drama in the first 15 mins of the second half. Australia levels the score.
#
# #FRA 1:1 #AUS
# #WorldCup #3Sports
# ----------
# Date d'envoi : 2018-06-16 11:47:05+00:00
#
# RT @tv3_ghana: 📌 Fortunes to change in second half?
#
# #FRA⁠ ⁠ 0-0 #AUS⁠ ⁠
#
# No goals in Kazan so far. France started well, Mbappe, Pogba &amp; G…
# ----------
# Date d'envoi : 2018-06-16 11:49:47+00:00
#
# GOAL!
#
# France 🇫🇷 2-1 Australia 🇦🇺
#
# Pogba sends his team forward with a fine goal pinged over the goalkeeper.
#
# #ConnectSports #WorldCup
# ----------
# Date d'envoi : 2018-06-16 11:50:37+00:00
#
# RT @onua951fm: The French could be on their way to 3 points. @paulpogba puts them ahead.
#
# #FRA 2:1 #AUS
# #WorldCup #3Sports https://t.co/Xr…
# ----------
# Date d'envoi : 2018-06-16 11:50:49+00:00
#
# RT @3SportsGh: PENALTY TO AUSTRALIA 🇦🇺
#
# #3Sports #WorldCup
# ----------
# Date d'envoi : 2018-06-16 11:50:54+00:00
#
# RT @3SportsGh: GOAL!
#
# Jedinak scores the penalty for the Socceroos.
#
# #3Sports #WorldCup
# ----------
# Date d'envoi : 2018-06-16 11:56:08+00:00
#
# FULL TIME: #FRA 2:1 #AUS
#
# #WorldCup #ConnectSports
# ----------
# Date d'envoi : 2018-06-16 11:57:52+00:00
#
# FULL-TIME!
#
# France steal the three points in Group C with a late Paul Pogba goal in a game that will be remembered… https://t.co/LsVgOueHRJ
# ----------
# Date d'envoi : 2018-06-16 12:46:13+00:00
#
# RT @onua951fm: 📌We saw Ronaldo's Portugal🇵🇹 last night, now we get to see Messi and Argentina🇦🇷
#
# Here's how both teams line up.
# #WorldCup #…
# ----------
# Date d'envoi : 2018-06-16 12:48:31+00:00
#
# 📌We saw Ronaldo's Portugal🇵🇹 last night, now we get to see Messi and Argentina🇦🇷
#
# Here's how both teams line up.… https://t.co/HJ4aJqFt4F
# ----------
# Date d'envoi : 2018-06-16 12:51:05+00:00
#
# What are your predictions for Argentina🇦🇷 vs Iceland 🇮🇸
#
# #WorldCup⁠ ⁠  #ConnectSports
# ----------
# Date d'envoi : 2018-06-16 12:58:39+00:00
#
# 📍We're giving you a chance to win yourself amazing gifts this #WorldCup period🎉
#
# All you have to do is answer a sim… https://t.co/BjQuh7pYSM
# ----------
# Date d'envoi : 2018-06-16 13:00:24+00:00
#
# 📌Iceland have qualified for their first World Cup and their second major tournament after Euro 2016 where they reac… https://t.co/5jvdV2KM5q
# ----------
# Date d'envoi : 2018-06-16 13:01:21+00:00
#
# 📌 The stage is set for another legend...
#
# Lionel Messi and his Argentina team-mates kick off their #WorldCup campai… https://t.co/jRzPsodlk2
# ----------
# Date d'envoi : 2018-06-16 13:18:25+00:00
#
# RT @onua951fm: It's been good 15 mins of football between #ARG🇦🇷 and #ISL🇮🇸
#
# We have a game on our hands.
# #WorldCup #3Sports
# ----------
# Date d'envoi : 2018-06-16 13:29:49+00:00
#
# We definitely have a game on our hands. It's #ARG🇦🇷 1: 1 #ISL 🇮🇸
#
# #WorldCup #ConnectSports https://t.co/pXePV717WQ
# ----------
# Date d'envoi : 2018-06-16 13:31:40+00:00
#
# RT @onua951fm: Argentina up and running!!! Aguero fires past Halldorsson to give Argentina lead.
#
# #WorldCup #3Sports
# ----------
# Date d'envoi : 2018-06-16 13:32:12+00:00
#
# GOAL!!!!
#
# Finbogasson gets Iceland back in it with after an awful error from the Argentine defence to gift them th… https://t.co/tiVl1CCAHL
# ----------
# Date d'envoi : 2018-06-16 13:33:56+00:00
#
# The feeling when you score your country’s first ever goal at the World Cup.
#
# #ConnectSports #WorldCup https://t.co/Cb2fnB2RWw
# ----------
# Date d'envoi : 2018-06-16 14:35:03+00:00
#
# RT @onua951fm: HALF TIME: Argentina🇦🇷 1:1 Iceland🇮🇸
#
# It's been a compelling half. More of the same
#
# #WorldCup #3Sports https://t.co/7zAm2Fe…
# ----------
# Date d'envoi : 2018-06-16 14:48:12+00:00
#
# 4 - Lionel Messi has missed four of the last seven penalties that he has taken for Barcelona &amp; Argentina combined (… https://t.co/GilCY0rZRF
# ----------
# Date d'envoi : 2018-06-16 14:49:47+00:00
#
# RT @3SportsGh: WATCH!
#
# That’s Aguero’s goal. Brilliant touch and take.
#
# #3Sports #WorldCup
#
#  https://t.co/JBOQ4XYYoj
# ----------
# Date d'envoi : 2018-06-16 15:03:42+00:00
#
# 🇮🇸 Iceland have won their first ever #WorldCup point
#
# #ConnectSports https://t.co/nQCTNvdq5w
# ----------
# Date d'envoi : 2018-06-16 15:38:08+00:00
#
# What do you make of the Iceland performance against Argentina this afternoon?
#
# #ConnectSports #WorldCup https://t.co/dNxAhrawJE
# ----------
# Date d'envoi : 2018-06-16 15:41:23+00:00
#
# Who's the better footballer?
#
# #ConnectSports #WorldCup
# ----------
# Date d'envoi : 2018-06-16 18:28:12+00:00
#
# FULL-TIME! #PER 0-1 #DEN
#
# Yussuf Yurary Poulsen's 59th-minute strike gives Denmark a narrow win over Peru who misse… https://t.co/ZJMbn4Yr1P
# ----------
# Date d'envoi : 2018-06-16 18:31:19+00:00
#
# Congratulations to Andreas Christensen - he played 80 minutes as #DEN got off to a winning start at the #WorldCup… https://t.co/JyTKQ1ndrU
# ----------
# Date d'envoi : 2018-06-16 18:33:12+00:00
#
# 🇩🇰 Congratulations to @ChrisEriksen8 who provided an assist as Denmark beat Peru 1-0 in their opening @FIFAWorldCup… https://t.co/183ujIo4aq
# ----------
# Date d'envoi : 2018-06-16 18:37:00+00:00
#
# We're onto our final match of today's #WorldCup action 🙌
#
# Here's the team news for #CRO vs #NGA
#
# What are your pre… https://t.co/ClBA0FI3hp
# ----------
# Date d'envoi : 2018-06-16 18:37:43+00:00
#
# RT @DeiTutuErnest: @Connect971fm @ChrisEriksen8 @FIFAWorldCup @ChrisEriksen8 was fantastic in their opening match at the #WorldCup but am e…
# ----------
# Date d'envoi : 2018-06-16 18:41:18+00:00
#
# Pre tournament hype.... Omo Naija
#
# Rebranding... Check 👌
# Jersey.... Check 👌
#
# #WorldCup #ConnectSports https://t.co/ULiJP9NQqh
# ----------
# Date d'envoi : 2018-06-16 18:45:10+00:00
#
# Played: 7
# Won: 1
#
# #Croatia's recent World Cup history has not gone well.
#
# Will they make it two wins from eight ton… https://t.co/e0QjuXAVfO
# ----------
# Date d'envoi : 2018-06-16 18:48:43+00:00
#
# This will be the first ever encounter between #Croatia and #Nigeria. Croatia's only previous World Cup game against… https://t.co/4HfLPIfgHr
# ----------
# Date d'envoi : 2018-06-16 18:51:03+00:00
#
# Send in your predictions
#
# Who wins tonight?
# #WorldCup #ConnectSports
# ----------
# Date d'envoi : 2018-06-16 18:57:28+00:00
#
# RT @idadzie81: Nigeria 1:2 Croatia
# #ConnectSports
# #WorldCup https://t.co/6SzE0jTYMl
# ----------
# Date d'envoi : 2018-06-16 19:39:09+00:00
#
# RT @3SportsGh: GOAL!
#
# Croatia 🇭🇷 take the lead after a Mandzukic header went in off the leg of Etebo.
#
# #3Sports #WorldCup
# ----------
# Date d'envoi : 2018-06-14 14:18:59+00:00
#
# RT @3SportsGh: WATCH!
#
# #3Sports #WorldCup https://t.co/BVQCHr097w
# ----------
# Date d'envoi : 2018-06-14 14:19:16+00:00
#
# 5 African countries are repping the continent at the World Cup, #Russia2018; however what are their chances of maki… https://t.co/AvvpZS5TVJ
# ----------
# Date d'envoi : 2018-06-14 14:34:01+00:00
#
# Who’s winning this one?
#
# #ConnectSports #WorldCup #Russia2018
# ----------
# Date d'envoi : 2018-06-14 06:42:13+00:00
#
# 📌The World Cup Starts Today.
#
# Scrap any plans you have for the next four and half weeks 😍😍🏆
#
# #ConnectSports… https://t.co/F6C3H1pf2N
# ----------
# Date d'envoi : 2018-06-14 18:19:20+00:00
#
# RT @onua951fm: FULL TIME: #RUS 5:0 #KSA
#
# The #WorldCup promises a lot of goals. #3Sports https://t.co/a5cDOYpRkD
# ----------
# Date d'envoi : 2018-06-14 18:19:40+00:00
#
# RT @tv3_ghana: 📌 There's only one way you're going to enjoy the #WorldCup.
#
# ❗️The goals.
#
# ❗️Breaking news.
#
# ❗️Instant analysis.
#
# ❗️Expert r…
# ----------
# Date d'envoi : 2018-06-15 07:33:48+00:00
#
# RT @tv3_ghana: 📌 The first game gets underway...
#
# Russia🇷🇺 0:0 Saudi Arabia🇸🇦
#
# #WorldCup #3Sports. https://t.co/FlsFD2itxv
# ----------
# Date d'envoi : 2018-06-15 09:40:42+00:00
#
# 📌Get every #WorldCup Breaking News, Exclusive interviews, Expert opinions, Social Media interactions goals and behi… https://t.co/DkSH4EVFsi
# ----------
# Date d'envoi : 2018-06-15 09:48:46+00:00
#
# RT @3SportsGh: Uruguay is the first of two tricky games for #Egy at #Russia2018.
#
# How far can the Pharaohs go?
#
# #3Sports https://t.co/fkQM…
# ----------
# Date d'envoi : 2018-06-15 09:56:29+00:00
#
# 📌Two African teams are in action today. What are your predictions for the games?
#
# #EGY⁠ ⁠ vs #URU⁠ ⁠ - 1200hrs GMT… https://t.co/Hk6FaluUVH
# ----------
# Date d'envoi : 2018-06-15 09:59:51+00:00
#
# Morocco have a tough group campaign in store at #Russia2018.
#
# #WorldCup #ConnectSports https://t.co/MpzZek8Pyl
# ----------
# Date d'envoi : 2018-06-15 10:01:44+00:00
#
# Uruguay is the first of two tricky games for #Egy at #Russia2018.
#
# How far can the Pharaohs go?
#
# #WorldCup… https://t.co/2cMWg9YYzG
# ----------
# Date d'envoi : 2018-06-15 10:05:34+00:00
#
# Africa makes its debut at #Russia2018 today with two big returnees'
#
# #Egy are back at the #WorldCup for the first t… https://t.co/UDD6JPjUrb
# ----------
# Date d'envoi : 2018-06-15 10:10:21+00:00
#
# The #WorldCup got off to a flying start yesterday. Who is ready for Matchday 2?
#
# #HelloRussia #ConnectSports
# ----------
# Date d'envoi : 2018-06-15 10:12:01+00:00
#
# 📍Are you ready for Match Day 2?
#
# 📍All kick-offs displayed in GMT+3 (Moscow time).
#
# #WorldCup
# #ConnectSports https://t.co/CDKLycx1Ff
# ----------
# Date d'envoi : 2018-06-14 09:26:15+00:00
#
# 📌The. World. Cup. Starts. Today.
#
# Scrap any plans you have for the next four and a half weeks 😍🏆
#
# Get every… https://t.co/cDqR0caFrQ
# ----------
# Date d'envoi : 2018-06-15 13:01:40+00:00
#
# 📍We're giving you a chance to win yourself amazing gifts this #WorldCup period🎉
#
# All you have to do is answer a sim… https://t.co/j7phI9HSZL
# ----------
# Date d'envoi : 2018-06-15 13:03:30+00:00
#
# RT @onua951fm: HALF TIME: #EGY 0:0 #URU
# It's been a pretty even half
#
# #WorldCup #3Sports https://t.co/RumvHi3ghq
# ----------
# Date d'envoi : 2018-06-15 13:04:02+00:00
#
# RT @onua951fm: 📌 Some Salah magic needed?
#
# Egypt are so far winless at the #WorldCup, drawing two and losing two of their four games. In fa…
# ----------
# Date d'envoi : 2018-06-15 13:04:57+00:00
#
# RT @onua951fm: Today is Morocco's first appearance since a 3-0 victory over Scotland in 1998.
#
# Welcome back to the #WorldCup @EnMaroc! 🎉 #…
# ----------
# Date d'envoi : 2018-06-15 13:05:05+00:00
#
# RT @onua951fm: 📌Mo Salah is not included in #EGY starting line up.
#
# #WorldCup #3Sports https://t.co/EY0K8aFeBM
# ----------
# Date d'envoi : 2018-06-15 13:10:20+00:00
#
# RT @onua951fm: Here's how #URU will line up against #EGY in today's #WorldCup encounter.
#
# #3Sports https://t.co/2MOAjd9NlY
# ----------
# Date d'envoi : 2018-06-15 13:48:21+00:00
#
# RT @tv3_ghana: 📌A poor first half of football.
#
# Half-time: Below-par Uruguay and Luis Suarez frustrated after 45 minutes against the Salah-…
# ----------
# Date d'envoi : 2018-06-15 15:02:31+00:00
#
# RT @tv3_ghana: 📌 Heartbreak. A dagger through the heart. A kick in the teeth.
#
# FT: #Egypt 0-1 #Uruguay. Jose Gimenez heads home in the 89th…
# ----------
# Date d'envoi : 2018-06-15 15:07:31+00:00
#
# #URU have won their opening game at the #WorldCup for the first time in 48 years. It’s been a long time coming.… https://t.co/k3v23uNqiX
# ----------
# Date d'envoi : 2018-06-15 15:09:27+00:00
#
# FULL TIME: #EGY 0:1 #URU
#
# Uruguay left it late to break Egyptian hearts.
# #WorldCup #ConnectSports https://t.co/XPwTsffSew
# ----------
# Date d'envoi : 2018-06-15 15:10:29+00:00
#
# 📍Ready for the next round of games?
#
# This is how Morocco 🇲🇦 &amp; Iran 🇮🇷 line up.
#
# #WorldCup #ConnectSports https://t.co/5AYzSJjUS6
# ----------
# Date d'envoi : 2018-06-15 15:18:54+00:00
#
# 📌 Morocco and Iran kick off their #WorldCup campaign both looking for an early advantage.
#
# With group favourites Sp… https://t.co/LTUZsBwbma
# ----------
# Date d'envoi : 2018-06-15 15:20:57+00:00
#
# 📌 Morocco and Iran kick off their #WorldCup campaign both looking for an early advantage.
#
# With group favourites Sp… https://t.co/2kOlxgRjVD
# ----------
# Date d'envoi : 2018-06-14 10:02:42+00:00
#
# 📌 #HelloRussia
# It's the Maiden Show to build up #WorldCup 2018.
# @WilsonAmpofo is seated...
#
# Get every #WorldCup… https://t.co/BiNHvP2oMW
# ----------
# Date d'envoi : 2018-06-15 17:36:56+00:00
#
# 📌Another heartbreak. Another drama.
#
# Iran defeats Morocco 1-0 on an own goal in stoppage time.
#
# This gives Iran⁠ ⁠g… https://t.co/pjnlD9jwPx
# ----------
# Date d'envoi : 2018-06-15 17:38:42+00:00
#
# The teams for Portugal vs Spain have been confirmed.
#
# #WorldCup #ConnectSports https://t.co/EkXK8LKbHE
# ----------
# Date d'envoi : 2018-06-15 17:41:06+00:00
#
# RT @3SportsGh: Iran defeated Morocco in the opening game of the #WorldCup courtesy an own goal from Bouhadouz. Despair.
#
# #3Sports https://…
# ----------
# Date d'envoi : 2018-06-15 17:46:53+00:00
#
# 📌 From the hills to the valleys, the game everyone's been waiting for.
#
# The tasty Spain vs Portugal game.
#
# The 2010… https://t.co/Qm592fvS1z
# ----------
# Date d'envoi : 2018-06-15 17:47:01+00:00
#
# RT @neequayeboye1: all eyes on this game . https://t.co/GS6ZR2qs9S
# ----------
# Date d'envoi : 2018-06-15 18:09:32+00:00
#
# RT @3SportsGh: GOAL!
#
# Ronaldo scores from the spot after he was tripped in the box less than 3 minutes into the game.
#
# Portugal 🇵🇹 1-0 Sp…
# ----------
# Date d'envoi : 2018-06-15 18:13:28+00:00
#
# RT @3fm927: 📌 Some #3Sports stats for you..
#
# Portugal &amp; Spain's only previous #WorldCup encounter was in 2010, with Spain winning 1-0 in th…
# ----------
# Date d'envoi : 2018-06-15 18:14:22+00:00
#
# 📌 Who wins the tactical battle? Whose game plan will be reign supreme?
#
# The formations that both #Portugal and… https://t.co/1feGyyt6UR
# ----------
# Date d'envoi : 2018-06-15 18:16:00+00:00
#
# RT @tv3_ghana: 📌 From the hills to the valleys, the game everyone's been waiting for.
#
# The tasty Spain vs Portugal game.
#
# The 2010 #WorldCu…
# ----------
# Date d'envoi : 2018-06-15 18:17:31+00:00
#
# “De Gea, best goalkeeper in the world?
#
# Not on my watch!”
#
# Probably what run through Ronaldo’s head as he gave Port… https://t.co/WKLQ0Vfrzr
# ----------
# Date d'envoi : 2018-06-15 18:21:12+00:00
#
# RT @OtiAdjei: Heard commentator say Ronaldo is the first player to score at eight successive major tournaments so I decided to check on @AS…
# ----------
# Date d'envoi : 2018-06-15 18:34:15+00:00
#
# GOAL! #POR 1-1 #ESP
#
# Brilliant composure from Diego Costa as he twists and turns before  firing past the goalkeepe… https://t.co/GltlKTOg9L
# ----------
# URLs complètes contenus dans les tweets de l'utilisateur :
# ['https://twitter.com/i/web/status/1007726762225258497', 'https://twitter.com/i/web/status/1007727501139959809', 'https://twitter.com/i/web/status/1007916769225465857', 'https://twitter.com/i/web/status/1007918331628843008', 'https://twitter.com/i/web/status/1007923600211537920', 'https://twitter.com/i/web/status/1007924191453204481', 'https://twitter.com/i/web/status/1007955415005528064', 'https://twitter.com/i/web/status/1007968161738698752', 'https://twitter.com/i/web/status/1007970711669964800', 'https://twitter.com/i/web/status/1007971153728671746', 'https://twitter.com/i/web/status/1007971392468471810', 'https://twitter.com/i/web/status/1007979155571519491', 'https://twitter.com/i/web/status/1007998278997245953', 'https://twitter.com/i/web/status/1008053644544102401', 'https://twitter.com/i/web/status/1008054430523166721', 'https://twitter.com/i/web/status/1008054902768259073', 'https://twitter.com/i/web/status/1008055861300940801', 'https://twitter.com/i/web/status/1008057917495562240', 'https://twitter.com/i/web/status/1008058808306937856', 'https://twitter.com/Connect971fm/status/1008059398013554689', 'https://twitter.com/i/web/status/1007266223535599616', 'https://twitter.com/i/web/status/1007151204365893632', 'https://twitter.com/i/web/status/1007558507049218048', 'https://twitter.com/i/web/status/1007562481789751296', 'https://twitter.com/i/web/status/1007563800994877440', 'https://twitter.com/i/web/status/1007564767614169088', 'https://twitter.com/i/web/status/1007192484945022976', 'https://twitter.com/i/web/status/1007609081585168384', 'https://twitter.com/i/web/status/1007640755412889600', 'https://twitter.com/i/web/status/1007643620520988673', 'https://twitter.com/i/web/status/1007644136403623937', 'https://twitter.com/i/web/status/1007201654951874561', 'https://twitter.com/i/web/status/1007678358031945729', 'https://twitter.com/i/web/status/1007680859430940673', 'https://twitter.com/Connect971fm/status/1007678801688526848', 'https://twitter.com/i/web/status/1007687774617722881', 'https://twitter.com/i/web/status/1007688570696622081', 'https://twitter.com/i/web/status/1007692781891018753']

# %% [markdown]
# ## 4. Getting all users and going through the links in their tweets

# %%
users_urls: dict[str, list] = {}
for user, tweets in users.items():
        urls = []
        for tweet in tweets:
            url = [url["expanded_url"] for url in tweet["entities"]["urls"]]
            for i, u in enumerate(url):
                if u.startswith("https://twitter.com"):
                    url.pop(i)
            urls.extend(url)
        if urls:
            users_urls[user] = urls
print(users_urls)
# Out:
# {'127680123': ['https://www.theguardian.com/football/2018/jun/01/alireza-beiranvand-sleeping-rough-world-cup-iran-goalkeeper?CMP=share_btn_tw'], '3300214125': ['https://www.pscp.tv/w/bfZ2tjFkclFla29hWmRiamJ8MU1ueG5aQllRWk54TymkO7spFvA0pZedpF03YiXna-zr24RXRNL-aTJJ-nNb'], '1249811761': ['http://lfc.tv/AHDh'], '3501989602': ['https://bracket2018.mlssoccer.com/#league/standings/1257?code=VMS3Z9HL', 'http://www.arenafanatic.com/matts-sports-corner'], '19822894': ['http://untp.beer/s/b351233271'], '301954928': ['https://paper.li/CIMAGES/1343516871?edition_id=683cb880-7112-11e8-9cca-0cc47a0d1609', 'https://paper.li/CIMAGES/1343516871?edition_id=92f4e6a0-71db-11e8-9cca-0cc47a0d1609', 'https://paper.li/CIMAGES/1343516871?edition_id=a7e17f40-6fe4-11e8-9cca-0cc47a0d1609', 'https://paper.li/CIMAGES/1343516871?edition_id=1323a400-6f80-11e8-b523-0cc47a0d1609'], '26325975': ['http://lfc.tv/AHDh'], '4773565166': ['http://bit.ly/2ybeeIO'], '6856442': ['https://www.youtube.com/watch?v=45NOP1OA-EQ&feature=youtu.be'], '2602388304': ['https://9gag.com/gag/azXYZGz?ref=tp'], '2171375114': ['http://bbc.in/2tacD08'], '80986907': ['http://780am.com'], '34395835': ['https://reut.rs/2sWgyOS'], '2330765646': ['http://bit.ly/2lc2DzH'], '93047351': ['https://ind.pn/2JEDb4w'], '2714522821': ['https://www.pscp.tv/w/bfPi9TFBbWp6T3pEbGFlRWV8MW1yR21ucW1ZV3FKeQMpYNR10gBVl1KExVKBgfHPbrjT6DOfjKDVjLTPz6pE'], '817957305173975040': ['http://t.asahi.com/pw3k'], '1085249270': ['http://bbc.in/2tacD08'], '392411896': ['http://x.ea.com/47700'], '76614123': ['http://lfc.tv/AHDh'], '825411950750347265': ['https://on.rt.com/97mp'], '2871069722': ['http://bit.ly/2JBRztq'], '43846520': ['https://goo.gl/ETq1dk']}
